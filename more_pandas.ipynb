# %%
#iloc, #loc .... methods to extract some values/records

# %%
import pandas as pd
iris = pd.read_csv('downloads/iris_data.csv')

# %%
iris.iloc[0:3,0:2]
# Out:
#    Unnamed: 0        source_id
# 0           0          reuters
# 1           1  the-irish-times
# 2           2  the-irish-times

# %%
# the only difference between iloc and loc is in LOC mwthod we give column rather than column number
#and the last index in row is inclusive in iloc but not here

# %%
iris.loc[0:3,("title","description")]
# Out:
#                                                title  \
# 0  NTSB says Autopilot engaged in 2018 California...
# 1       Unemployment falls to post-crash low of 5.2%
# 2  Louise Kennedy AW2019: Long coats, sparkling t...
# 3  North Korean footballer Han joins Italian gian...
#
#                                          description
# 0  The National Transportation Safety Board said ...
# 1  Latest monthly figures reflect continued growt...
# 2  Autumn-winter collection features designer’s g...
# 3  Han is the first North Korean player in the Se...

# %%
#dropping columns , to remove a column
# asix = 1 denoting the column, axis =0 dropping the column

# %%
iris.head()
# Out:
#    Unnamed: 0           source_id         source_name              author  \
# 0           0             reuters             Reuters   Reuters Editorial
# 1           1     the-irish-times     The Irish Times  Eoin Burke-Kennedy
# 2           2     the-irish-times     The Irish Times   Deirdre McQuillan
# 3           3  al-jazeera-english  Al Jazeera English          Al Jazeera
# 4           4            bbc-news            BBC News            BBC News
#
#                                                title  \
# 0  NTSB says Autopilot engaged in 2018 California...
# 1       Unemployment falls to post-crash low of 5.2%
# 2  Louise Kennedy AW2019: Long coats, sparkling t...
# 3  North Korean footballer Han joins Italian gian...
# 4  UK government lawyer says proroguing parliamen...
#
#                                          description  \
# 0  The National Transportation Safety Board said ...
# 1  Latest monthly figures reflect continued growt...
# ...

# %%
iris.drop('url',axis=1)
# Out:
#        Unnamed: 0           source_id         source_name  \
# 0               0             reuters             Reuters
# 1               1     the-irish-times     The Irish Times
# 2               2     the-irish-times     The Irish Times
# 3               3  al-jazeera-english  Al Jazeera English
# 4               4            bbc-news            BBC News
# ...           ...                 ...                 ...
# 10432       10432            abc-news            ABC News
# 10433       10433             reuters             Reuters
# 10434       10434                 cnn                 CNN
# 10435       10435            cbs-news            CBS News
# 10436       10436            cbs-news            CBS News
#
#                        author  \
# 0           Reuters Editorial
# 1          Eoin Burke-Kennedy
# 2           Deirdre McQuillan
# 3                  Al Jazeera
# 4                    BBC News
# ...                       ...
# 10432    The Associated Press
# ...

# %%
irsi
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-e7ad124936c5> in <module>
# ----> 1 irsi
#
# NameError: name 'irsi' is not defined

# %%
iris
# Out:
#        Unnamed: 0           source_id         source_name  \
# 0               0             reuters             Reuters
# 1               1     the-irish-times     The Irish Times
# 2               2     the-irish-times     The Irish Times
# 3               3  al-jazeera-english  Al Jazeera English
# 4               4            bbc-news            BBC News
# ...           ...                 ...                 ...
# 10432       10432            abc-news            ABC News
# 10433       10433             reuters             Reuters
# 10434       10434                 cnn                 CNN
# 10435       10435            cbs-news            CBS News
# 10436       10436            cbs-news            CBS News
#
#                        author  \
# 0           Reuters Editorial
# 1          Eoin Burke-Kennedy
# 2           Deirdre McQuillan
# 3                  Al Jazeera
# 4                    BBC News
# ...                       ...
# 10432    The Associated Press
# ...

# %%
iris.min() # to get the min value of all the columns
# Out:
# Unnamed: 0                             0
# source_id                              1
# source_name                        460.0
# top_article                            0
# engagement_reaction_count              0
# engagement_comment_count               0
# engagement_share_count                 0
# engagement_comment_plugin_count        0
# dtype: object

# %%
iris.max()
# Out:
# Unnamed: 0                                           10436
# source_id                          the-wall-street-journal
# source_name                        The Wall Street Journal
# top_article                                              1
# engagement_reaction_count                           354132
# engagement_comment_count                             48490
# engagement_share_count                               39422
# engagement_comment_plugin_count                         15
# dtype: object

# %%
def double_make(s):
    return s*2

# %%
soccer = pd.read_csv('downloads/soccer.csv')

# %%
soccer.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
soccer[['Marking', 'StandingTackle']].apply(double_make)
# Out:
#        Marking  StandingTackle
# 0         66.0            56.0
# 1         56.0            62.0
# 2         54.0            48.0
# 3         30.0            42.0
# 4        136.0           116.0
# ...        ...             ...
# 18202     80.0            96.0
# 18203     44.0            30.0
# 18204     64.0            26.0
# 18205     40.0            50.0
# 18206     80.0            86.0
#
# [18207 rows x 2 columns]

# %%
soccer
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 0               0  158023            L. Messi   31
# 1               1   20801   Cristiano Ronaldo   33
# 2               2  190871           Neymar Jr   26
# 3               3  193080              De Gea   27
# 4               4  192985        K. De Bruyne   27
# ...           ...     ...                 ...  ...
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %% [raw]
# soccer.head()

# %%
soccer.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
soccer.sort_values(by = 'Overall')
# Out:
#        Unnamed: 0      ID               Name  Age  \
# 18206       18206  246269          G. Nugent   16
# 18186       18186  240917       Zhang Yufeng   20
# 18187       18187  240158          C. Ehlich   19
# 18188       18188  240927         L. Collins   17
# 18189       18189  240160         A. Kaltner   18
# ...           ...     ...                ...  ...
# 4               4  192985       K. De Bruyne   27
# 3               3  193080             De Gea   27
# 2               2  190871          Neymar Jr   26
# 1               1   20801  Cristiano Ronaldo   33
# 0               0  158023           L. Messi   31
#
#                                                 Photo Nationality  \
# 18206  https://cdn.sofifa.org/players/4/19/246269.png     England
# 18186  https://cdn.sofifa.org/players/4/19/240917.png    China PR
# 18187  https://cdn.sofifa.org/players/4/19/240158.png     Germany
# 18188  https://cdn.sofifa.org/players/4/19/240927.png       Wales
# ...
